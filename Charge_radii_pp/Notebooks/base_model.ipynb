# %%
import numpy as np
# import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import corner 
import scienceplots 
plt.style.use('science')

# %%
# %load_ext autoreload
# %autoreload 2
from source_functions.config import base_models, colors_sets
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 3 from source_functions.config import base_models, colors_sets
#
# ModuleNotFoundError: No module named 'source_functions'
